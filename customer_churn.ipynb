# %% [markdown]
# <a href="https://colab.research.google.com/github/ZohaAsghar/Customer-Churn/blob/main/customer_churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
import kagglehub
path = kagglehub.dataset_download("barun2104/telecom-churn")
# Out:
# ...
# 100%|██████████| 45.5k/45.5k [00:00<00:00, 12.0MB/s]
# Extracting files...

# %%
df=pd.read_csv(os.path.join(path,"telecom_churn.csv"))
df
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1       2.70
# 1         0           107                1         1       3.70
# 2         0           137                1         0       0.00
# 3         0            84                0         0       0.00
# 4         0            75                0         0       0.00
# ...     ...           ...              ...       ...        ...
# 3328      0           192                1         1       2.67
# 3329      0            68                1         0       0.34
# 3330      0            28                1         0       0.00
# 3331      0           184                0         0       0.00
# 3332      0            74                1         1       3.70
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1    265.1       110           89.0        9.87      10.0
# ...

# %%
df.describe()
# Out:
#              Churn  AccountWeeks  ContractRenewal     DataPlan    DataUsage  \
# count  3333.000000   3333.000000      3333.000000  3333.000000  3333.000000
# mean      0.144914    101.064806         0.903090     0.276628     0.816475
# std       0.352067     39.822106         0.295879     0.447398     1.272668
# min       0.000000      1.000000         0.000000     0.000000     0.000000
# 25%       0.000000     74.000000         1.000000     0.000000     0.000000
# 50%       0.000000    101.000000         1.000000     0.000000     0.000000
# 75%       0.000000    127.000000         1.000000     1.000000     1.780000
# max       1.000000    243.000000         1.000000     1.000000     5.400000
#
#        CustServCalls      DayMins     DayCalls  MonthlyCharge   OverageFee  \
# count    3333.000000  3333.000000  3333.000000    3333.000000  3333.000000
# mean        1.562856   179.775098   100.435644      56.305161    10.051488
# ...

# %%
df.head()
# Out:
#    Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0      0           128                1         1        2.7              1
# 1      0           107                1         1        3.7              1
# 2      0           137                1         0        0.0              0
# 3      0            84                0         0        0.0              2
# 4      0            75                0         0        0.0              3
#
#    DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0    265.1       110           89.0        9.87      10.0
# 1    161.6       123           82.0        9.78      13.7
# 2    243.4       114           52.0        6.06      12.2
# 3    299.4        71           57.0        3.10       6.6
# 4    166.7       113           41.0        7.42      10.1

# %%
df.tail()
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 3328      0           192                1         1       2.67
# 3329      0            68                1         0       0.34
# 3330      0            28                1         0       0.00
# 3331      0           184                0         0       0.00
# 3332      0            74                1         1       3.70
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 3328              2    156.2        77           71.7       10.78       9.9
# 3329              3    231.1        57           56.4        7.67       9.6
# 3330              2    180.8       109           56.0       14.44      14.1
# 3331              2    213.8       105           50.0        7.98       5.0
# 3332              0    234.4       113          100.0       13.30      13.7

# %%
df.fillna(1)
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1       2.70
# 1         0           107                1         1       3.70
# 2         0           137                1         0       0.00
# 3         0            84                0         0       0.00
# 4         0            75                0         0       0.00
# ...     ...           ...              ...       ...        ...
# 3328      0           192                1         1       2.67
# 3329      0            68                1         0       0.34
# 3330      0            28                1         0       0.00
# 3331      0           184                0         0       0.00
# 3332      0            74                1         1       3.70
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1    265.1       110           89.0        9.87      10.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Churn            3333 non-null   int64
#  1   AccountWeeks     3333 non-null   int64
#  2   ContractRenewal  3333 non-null   int64
#  3   DataPlan         3333 non-null   int64
#  4   DataUsage        3333 non-null   float64
#  5   CustServCalls    3333 non-null   int64
#  6   DayMins          3333 non-null   float64
#  7   DayCalls         3333 non-null   int64
#  8   MonthlyCharge    3333 non-null   float64
#  9   OverageFee       3333 non-null   float64
#  10  RoamMins         3333 non-null   float64
# dtypes: float64(5), int64(6)
# memory usage: 286.6 KB

# %%
df.value_counts()
# Out:
# Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 1      225           1                0         0.30       0              165.4    106       55.0           13.69       8.7         1
# 0      1             1                0         0.00       0              123.8    113       42.0           11.81       3.7         1
#                                                            1              144.8    107       35.0           5.63        13.8        1
#                                                                           175.2    74        43.0           7.59        5.3         1
#                                                 0.25       1              196.1    107       61.5           14.83       7.0         1
#                                                                                                                                    ..
# ...

# %%
df.isnull()
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0     False         False            False     False      False
# 1     False         False            False     False      False
# 2     False         False            False     False      False
# 3     False         False            False     False      False
# 4     False         False            False     False      False
# ...     ...           ...              ...       ...        ...
# 3328  False         False            False     False      False
# 3329  False         False            False     False      False
# 3330  False         False            False     False      False
# 3331  False         False            False     False      False
# 3332  False         False            False     False      False
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0             False    False     False          False       False     False
# ...

# %%
from sklearn.preprocessing import LabelEncoder
coder=LabelEncoder()

# %%
df["DataUsage"].value_counts()
# Out:
# DataUsage
# 0.00    1813
# 0.31      41
# 0.21      39
# 0.29      36
# 0.26      34
#         ...
# 4.48       1
# 0.78       1
# 1.40       1
# 0.65       1
# 0.68       1
# Name: count, Length: 174, dtype: int64

# %%
df["DataUsage"] = df["DataUsage"].astype(str)
df["DataUsage"] = coder.fit_transform(df["DataUsage"])
df
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1        103
# 1         0           107                1         1        140
# 2         0           137                1         0          0
# 3         0            84                0         0          0
# 4         0            75                0         0          0
# ...     ...           ...              ...       ...        ...
# 3328      0           192                1         1        102
# 3329      0            68                1         0         24
# 3330      0            28                1         0          0
# 3331      0           184                0         0          0
# 3332      0            74                1         1        140
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1    265.1       110           89.0        9.87      10.0
# ...

# %%
df["DayMins"].value_counts()
# Out:
# DayMins
# 159.5    8
# 174.5    8
# 154.0    8
# 175.4    7
# 162.3    7
#         ..
# 332.9    1
# 120.7    1
# 129.1    1
# 258.6    1
# 223.4    1
# Name: count, Length: 1667, dtype: int64

# %%
df["DayMins"]=df["DayMins"].astype(str)
df["DayMins"]=coder.fit_transform(df["DayMins"])
df
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1        103
# 1         0           107                1         1        140
# 2         0           137                1         0          0
# 3         0            84                0         0          0
# 4         0            75                0         0          0
# ...     ...           ...              ...       ...        ...
# 3328      0           192                1         1        102
# 3329      0            68                1         0         24
# 3330      0            28                1         0          0
# 3331      0           184                0         0          0
# 3332      0            74                1         1        140
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1     1305       110           89.0        9.87      10.0
# ...

# %%
df["MonthlyCharge"].value_counts()
# Out:
# MonthlyCharge
# 50.0     84
# 46.0     75
# 45.0     74
# 49.0     73
# 54.0     72
#          ..
# 77.4      1
# 44.6      1
# 103.1     1
# 76.2      1
# 100.0     1
# Name: count, Length: 627, dtype: int64

# %%
df["MonthlyCharge"]=df["MonthlyCharge"].astype(str)
df["MonthlyCharge"]=coder.fit_transform(df["MonthlyCharge"])
df
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1        103
# 1         0           107                1         1        140
# 2         0           137                1         0          0
# 3         0            84                0         0          0
# 4         0            75                0         0          0
# ...     ...           ...              ...       ...        ...
# 3328      0           192                1         1        102
# 3329      0            68                1         0         24
# 3330      0            28                1         0          0
# 3331      0           184                0         0          0
# 3332      0            74                1         1        140
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1     1305       110            563        9.87      10.0
# ...

# %%
df["OverageFee"].value_counts()
# Out:
# OverageFee
# 8.50     13
# 10.19    11
# 8.36     11
# 8.09     11
# 8.80     10
#          ..
# 13.30     1
# 12.74     1
# 14.59     1
# 6.31      1
# 3.38      1
# Name: count, Length: 1024, dtype: int64

# %%
df["OverageFee"]=df["OverageFee"].astype(str)
df["OverageFee"]=coder.fit_transform(df["OverageFee"])
df
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1        103
# 1         0           107                1         1        140
# 2         0           137                1         0          0
# 3         0            84                0         0          0
# 4         0            75                0         0          0
# ...     ...           ...              ...       ...        ...
# 3328      0           192                1         1        102
# 3329      0            68                1         0         24
# 3330      0            28                1         0          0
# 3331      0           184                0         0          0
# 3332      0            74                1         1        140
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1     1305       110            563        1011      10.0
# ...

# %%
df["RoamMins"].value_counts()
# Out:
# RoamMins
# 10.0    62
# 11.3    59
# 9.8     56
# 10.9    56
# 10.6    53
#         ..
# 3.4      1
# 18.3     1
# 1.1      1
# 2.4      1
# 2.5      1
# Name: count, Length: 162, dtype: int64

# %%
df["RoamMins"]=df["RoamMins"].astype(str)
df["RoamMins"]=coder.fit_transform(df["RoamMins"])
df
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1        103
# 1         0           107                1         1        140
# 2         0           137                1         0          0
# 3         0            84                0         0          0
# 4         0            75                0         0          0
# ...     ...           ...              ...       ...        ...
# 3328      0           192                1         1        102
# 3329      0            68                1         0         24
# 3330      0            28                1         0          0
# 3331      0           184                0         0          0
# 3332      0            74                1         1        140
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1     1305       110            563        1011         3
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **DayMins VS MonthlyCharge**

# %%
plt.plot(df["DayMins"],df["MonthlyCharge"])

plt.xlabel("DayMins")
plt.ylabel("MonthlyCharge")
plt.title('DayMins VS MonthlyCharge ')
plt.show()

# %%
plt.scatter(df["DayMins"],df["MonthlyCharge"])

plt.xlabel("DayMins")
plt.ylabel("MonthlyCharge")
plt.title('DayMins VS MonthlyCharge ')
plt.show()

# %%
plt.bar(df["DayMins"],df["MonthlyCharge"])

plt.xlabel("DayMins")
plt.ylabel("MonthlyCharge")
plt.title('DayMins VS MonthlyCharge ')
plt.show()

# %%
plt.stem(df["DayMins"],df["MonthlyCharge"])

plt.xlabel("DayMins")
plt.ylabel("MonthlyCharge")
plt.title('DayMins VS MonthlyCharge ')
plt.show()

# %%
plt.hist(df["DayMins"])

plt.xlabel("DayMins")
plt.ylabel("Frequency") # Changed ylabel to reflect histogram output
plt.title('Distribution of DayMins') # Changed title to reflect histogram output
plt.show()

# %% [markdown]
# **DataUsage VS MonthlyCharge**

# %%
plt.plot(df["DataUsage"],df["MonthlyCharge"])

plt.xlabel("DataUsage")
plt.ylabel("MonthlyCharge")
plt.title('DataUsage VS MonthlyCharge ')
plt.show()

# %%
plt.scatter(df["DataUsage"],df["MonthlyCharge"])

plt.xlabel("DataUsage")
plt.ylabel("MonthlyCharge")
plt.title('DataUsage VS MonthlyCharge ')
plt.show()

# %%
plt.stem(df["DataUsage"],df["MonthlyCharge"])

plt.xlabel("DataUsage")
plt.ylabel("MonthlyCharge")
plt.title('DataUsage VS MonthlyCharge ')
plt.show()

# %%
plt.hist(df["DataUsage"])

plt.xlabel("DataUsage")
plt.ylabel("Frequency") # Changed ylabel to reflect histogram output
plt.title('Distribution of DataUsage') # Changed title to reflect histogram output
plt.show()

# %% [markdown]
# **DayCall VS DayMins**

# %%
plt.plot(df["DayCalls"],df["DayMins"])

plt.xlabel("DayCall")
plt.ylabel("DayMins")
plt.title('DayCall VS DayMins')
plt.show()

# %%
plt.bar(df["DayCalls"],df["DayMins"])

plt.xlabel("DayCall")
plt.ylabel("DayMins")
plt.title('DayCall VS DayMins')
plt.show()

# %%
plt.scatter(df["DayCalls"],df["DayMins"])

plt.xlabel("DayCall")
plt.ylabel("DayMins")
plt.title('DayCall VS DayMins')
plt.show()

# %%
plt.stem(df["DayCalls"],df["DayMins"])

plt.xlabel("DayCall")
plt.ylabel("DayMins")
plt.title('DayCall VS DayMins')
plt.show()

# %%
plt.hist(df["DayCalls"])

plt.xlabel("DayCall")
plt.ylabel("Frequency")
plt.title('Distribution of DayCalls')
plt.show()

# %%
import seaborn as seb

# %% [markdown]
# **DayMins VS MonthlyCharge**

# %%
seb.barplot(x="DayMins", y="MonthlyCharge", data=df)
plt.xlabel("DayMins")
plt.ylabel("MonthlyCharge")
plt.title('DayMins VS MonthlyCharge ')
plt.show()

# %%
seb.scatterplot(x="DayMins", y="MonthlyCharge", data=df)
plt.xlabel("DayMins")
plt.ylabel("MonthlyCharge")
plt.title('DayMins VS MonthlyCharge ')
plt.show()

# %%
seb.histplot(x="DayMins", y="MonthlyCharge", data=df)
plt.xlabel("DayMins")
plt.ylabel("MonthlyCharge")
plt.title('DayMins VS MonthlyCharge ')
plt.show()

# %%
seb.lineplot(x="DayMins", y="MonthlyCharge", data=df)
plt.xlabel("DayMins")
plt.ylabel("MonthlyCharge")
plt.title('DayMins VS MonthlyCharge ')
plt.show()

# %%
seb.violinplot(x="DayMins", y="MonthlyCharge", data=df)
plt.xlabel("DayMins")
plt.ylabel("MonthlyCharge")
plt.title('DayMins VS MonthlyCharge ')
plt.show()

# %%
seb.boxplot(x="DayMins", y="MonthlyCharge", data=df)
plt.xlabel("DayMins")
plt.ylabel("MonthlyCharge")
plt.title('DayMins VS MonthlyCharge ')
plt.show()

# %% [markdown]
# **DataUsage VS MonthlyCharge**

# %%
seb.barplot(x=df["DataUsage"],y=df["MonthlyCharge"])
plt.xlabel("DataUsage")
plt.ylabel("MonthlyCharge")
plt.title('DataUsage VS MonthlyCharge ')
plt.show()

# %%
seb.histplot(x=df["DataUsage"],y=df["MonthlyCharge"])
plt.xlabel("DataUsage")
plt.ylabel("MonthlyCharge")
plt.title('DataUsage VS MonthlyCharge ')
plt.show()

# %%
seb.lineplot(x=df["DataUsage"],y=df["MonthlyCharge"])
plt.xlabel("DataUsage")
plt.ylabel("MonthlyCharge")
plt.title('DataUsage VS MonthlyCharge ')
plt.show()

# %%
seb.boxplot(x=df["DataUsage"],y=df["MonthlyCharge"])
plt.xlabel("DataUsage")
plt.ylabel("MonthlyCharge")
plt.title('DataUsage VS MonthlyCharge ')
plt.show()

# %%
seb.violinplot(x=df["DataUsage"],y=df["MonthlyCharge"])
plt.xlabel("DataUsage")
plt.ylabel("MonthlyCharge")
plt.title('DataUsage VS MonthlyCharge ')
plt.show()

# %%
seb.scatterplot(x=df["DataUsage"],y=df["MonthlyCharge"])
plt.xlabel("DataUsage")
plt.ylabel("MonthlyCharge")
plt.title('DataUsage VS MonthlyCharge ')
plt.show()

# %% [markdown]
# **DayCall VS DayMins**

# %%
seb.barplot(x=df["DayCalls"],y=df["DayMins"])
plt.xlabel("DayCall")
plt.ylabel("DayMins")
plt.title('DayCall VS DayMins')
plt.show()

# %%
seb.scatterplot(x=df["DayCalls"],y=df["DayMins"])
plt.xlabel("DayCall")
plt.ylabel("DayMins")
plt.title('DayCall VS DayMins')
plt.show()

# %%
seb.lineplot(x=df["DayCalls"],y=df["DayMins"])
plt.xlabel("DayCall")
plt.ylabel("DayMins")
plt.title('DayCall VS DayMins')
plt.show()

# %%
seb.boxplot(x=df["DayCalls"],y=df["DayMins"])
plt.xlabel("DayCall")
plt.ylabel("DayMins")
plt.title('DayCall VS DayMins')
plt.show()

# %%
seb.histplot(x=df["DayCalls"],y=df["DayMins"])
plt.xlabel("DayCall")
plt.ylabel("DayMins")
plt.title('DayCall VS DayMins')
plt.show()

# %%
seb.violinplot(x=df["DayCalls"],y=df["DayMins"])
plt.xlabel("DayCall")
plt.ylabel("DayMins")
plt.title('DayCall VS DayMins')
plt.show()

# %%
x=(df.drop(["Churn"],axis=1))
y=df["Churn"]

# %%
x
# Out:
#       AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0              128                1         1        103              1
# 1              107                1         1        140              1
# 2              137                1         0          0              0
# 3               84                0         0          0              2
# 4               75                0         0          0              3
# ...            ...              ...       ...        ...            ...
# 3328           192                1         1        102              2
# 3329            68                1         0         24              3
# 3330            28                1         0          0              2
# 3331           184                0         0          0              2
# 3332            74                1         1        140              0
#
#       DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1999 entries, 1014 to 3174
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AccountWeeks     1999 non-null   int64
#  1   ContractRenewal  1999 non-null   int64
#  2   DataPlan         1999 non-null   int64
#  3   DataUsage        1999 non-null   int64
#  4   CustServCalls    1999 non-null   int64
#  5   DayMins          1999 non-null   int64
#  6   DayCalls         1999 non-null   int64
#  7   MonthlyCharge    1999 non-null   int64
#  8   OverageFee       1999 non-null   int64
#  9   RoamMins         1999 non-null   int64
# dtypes: int64(10)
# memory usage: 171.8 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1334 entries, 438 to 668
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AccountWeeks     1334 non-null   int64
#  1   ContractRenewal  1334 non-null   int64
#  2   DataPlan         1334 non-null   int64
#  3   DataUsage        1334 non-null   int64
#  4   CustServCalls    1334 non-null   int64
#  5   DayMins          1334 non-null   int64
#  6   DayCalls         1334 non-null   int64
#  7   MonthlyCharge    1334 non-null   int64
#  8   OverageFee       1334 non-null   int64
#  9   RoamMins         1334 non-null   int64
# dtypes: int64(10)
# memory usage: 114.6 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1999 entries, 1014 to 3174
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 1999 non-null   int64
# dtypes: int64(1)
# memory usage: 31.2 KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1334 entries, 438 to 668
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 1334 non-null   int64
# dtypes: int64(1)
# memory usage: 20.8 KB

# %%
from sklearn.linear_model import LogisticRegression

# %%
modle=LogisticRegression()

# %%
modle.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=modle.predict(x_test)

# %%
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy=modle.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.8515742128935532

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
modle1=DecisionTreeClassifier()

# %%
modle.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
modle.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy=modle.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.8515742128935532

# %%
from sklearn.cluster import KMeans

# %%
modle2=KMeans()

# %%
modle.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
modle.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy=modle.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.8515742128935532

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
modle=RandomForestClassifier()

# %%
modle.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
modle.predict(x_test)
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
accuracy=modle.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.9235382308845578

# %%
from sklearn.svm import SVC

# %%
modle=SVC()

# %%
modle.fit(x_train,y_train)
# Out:
# SVC()

# %%
modle.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy=modle.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.8530734632683659

# %%
from sklearn.naive_bayes import GaussianNB

# %%
modle=GaussianNB()

# %%
modle.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
modle.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
accuracy=modle.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.841079460269865

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
moddel=KNeighborsClassifier()

# %%
moddel.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
moddel.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
moddel.score(x_test,y_test)
# Out:
# 0.8860569715142429
